# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
r = requests.get("https://www.ptt.cc/bbs/Food/index.html")

# %%
print(r.content.decode())
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Food 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Food/index.html"><span class="board-label">看板 </span>Food</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
a = requests.get("https://www.ptt.cc/bbs/Food/M.1501588363.A.F7B.html")

# %%
print(a.content.decode())
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>[食記] 香港銅鑼灣 點點心灣仔店 推薦港點餐廳 - 看板 Food - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="2016.NOV
# 圖文網誌版:
# http://bitesize.tw/2016-hongkong-04-dimdimsumhk/
# 第一次到香港，不能錯過的就是港式點心，
# 其實港點我愛吃的不出那幾樣：叉燒包、流沙包、鹹水角、豉汁鳳爪、潮州粉果，
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="[食記] 香港銅鑼灣 點點心灣仔店 推薦港點餐廳">
# <meta property="og:description" content="2016.NOV
# 圖文網誌版:
# http://bitesize.tw/2016-hongkong-04-dimdimsumhk/
# 第一次到香港，不能錯過的就是港式點心，
# 其實港點我愛吃的不出那幾樣：叉燒包、流沙包、鹹水角、豉汁鳳爪、潮州粉果，
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Food/M.1501588363.A.F7B.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# ...

# %%
bsa = BeautifulSoup(a.content.decode())
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file D:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
b = bsa.find("div", id="main-content")

# %%
b.text
# Out:
# '作者Furella (Furella)看板Food標題[食記] 香港銅鑼灣 點點心灣仔店 推薦港點餐廳時間Tue Aug  1 19:52:41 2017\n2016.NOV\n\n圖文網誌版:\n\nhttp://bitesize.tw/2016-hongkong-04-dimdimsumhk/\n\n\n第一次到香港，不能錯過的就是港式點心，\n其實港點我愛吃的不出那幾樣：叉燒包、流沙包、鹹水角、豉汁鳳爪、潮州粉果，\n幾乎去到港式飲茶店家，就總是會點這幾樣。\n我們這次下榻在銅鑼灣，其實大多數的餐廳也都在銅鑼灣或灣仔解決了，\n這家位於灣仔的點點心是我們這趟幾家港點吃下來，\n和妹妹同時感到最合胃口的一家，且價格平實，\n三個人吃下來不過台幣千元之譜，很值得再訪。\n\n前一天在會場音樂聽得很晚，吃個晚晚的宵夜文輝墨魚丸大王以後回到飯店也近午夜，\n三人各自梳洗完畢後早上根本就起不來吃早餐，\n乾脆睡到吃午餐的時間再起床覓食，直接往會場去。\n\n從我們飯店步行到點點心，會穿過一個很在地生活的傳統市場，\n各種魚獲、海鮮，新鮮蔬果與肉販從早市到中午都還活力十足的吆喝著。\n\n菜單上四五十樣點心讓我們眼花撩亂，\n不僅蒸的點心類有二十來樣、腸粉有四五樣、焗的烤的點心類也大概有十樣左右，\n還有份量較大的飯麵粥等等，我們三人食量沒那麼大，點的都以點心類為主。\n\n第一輪上桌的有白灼芥蘭菜、香煎蘿蔔糕與金沙肥豬仔（流沙包），\n台灣店開張之初紅極一時的豬仔流沙包果然了得！\n甫上桌的豬仔們剝開後流出的鹹蛋黃醬汁實在太迷人，鹹甜適中皮嫩餡兒多。\n芥蘭菜爽脆、蘿蔔糕細緻充滿蘿蔔的鮮甜味，\n這兒的蘿蔔糕裡頭特意用了比較大塊一點的蘿蔔角，水分含量更高，相當好吃。\n\n接著繼續上蒸類的點心，發現三個人來吃點點心剛剛好，\n幾乎所有的點心類都是三隻一組，豉皇蒸鳳爪與巧製叉燒包都是我的心頭好，\n鳳爪蒸得軟爛滋味濃重、叉燒包的皮是略帶黏牙，\n鬆軟卻不會濕爛的好皮，包兒個頭小了一點，連帶的餡料也比較少，但不減其美味。\n\n第三輪的芥末咸水角與脆皮鮮蝦腸完全就是我的菜！\n咸水角外型精巧，內餡以芥末調味，雖是素菜卻有滋有味，\n外皮軟Q偏甜，炸得脆酥酥的非常可口。\n而這道脆皮鮮蝦腸可說是吃過最美味的一道，\n其他地方的還沒吃過這種價位比他美味的。\n蝦泥鑲在油條
# ...

# %%
C=defaultdict(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0f40b9fd5597> in <module>()
# ----> 1 C=defaultdict(int)
#
# NameError: name 'defaultdict' is not defined

# %%
bsa.findAll("span", class_="article-meta-value")
# Out:
# [<span class="article-meta-value">Furella (Furella)</span>,
#  <span class="article-meta-value">Food</span>,
#  <span class="article-meta-value">[食記] 香港銅鑼灣 點點心灣仔店 推薦港點餐廳</span>,
#  <span class="article-meta-value">Tue Aug  1 19:52:41 2017</span>]
